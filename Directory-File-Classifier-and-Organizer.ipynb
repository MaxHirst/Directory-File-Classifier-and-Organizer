# %%
import os
import time
import ipywidgets as widgets
from IPython.display import display
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# Widget for directory input
directory_input = widgets.Text(
    value='',
    placeholder='Enter directory path',
    description='Directory:',
    disabled=False
)

# Progress bar
progress_bar = widgets.IntProgress(
    value=0,
    min=0,
    max=100,
    step=1,
    description='Progress:',
    bar_style='info',
    orientation='horizontal'
)

# Display widgets
display(directory_input)
display(progress_bar)

# Enhanced dictionary of file categories and their extensions
categories = {
    'Images': ['jpeg', 'jpg', 'png', 'gif', 'bmp', 'tiff'],
    'PDFs': ['pdf'],
    'Documents': ['doc', 'docx', 'txt', 'rtf', 'odt'],
    'Spreadsheets': ['xls', 'xlsx', 'ods'],
    'Presentations': ['ppt', 'pptx', 'odp'],
    'Datasets': ['csv', 'xlsx', 'json', 'xml', 'sql'],
    'Videos': ['mp4', 'mkv', 'avi', 'mov', 'wmv'],
    'Audio': ['mp3', 'wav', 'aac', 'flac'],
    'Archives': ['zip', 'rar', 'tar', 'gz', '7z'],
    'Scripts': ['py', 'js', 'sh', 'bat'],
    'Executables': ['exe', 'bin', 'msi'],
    'Web': ['html', 'htm', 'css', 'js']
}

# Create a reverse lookup dictionary for file extensions
extension_to_category = {ext: category for category, extensions in categories.items() for ext in extensions}

def create_directories(directory):
    for category in categories:
        os.makedirs(os.path.join(directory, category), exist_ok=True)

# Function to classify a file
def classify_file(directory, filename):
    # Find the file extension
    extension = os.path.splitext(filename)[-1][1:]

    # Get the category from the reverse lookup dictionary
    category = extension_to_category.get(extension)
    if category:
        # Construct the file paths
        source_path = os.path.join(directory, filename)
        dest_path = os.path.join(directory, category, filename)

        # Move the file
        os.rename(source_path, dest_path)
        print(f'Moved {filename} to {category}')

# Classify all existing files in the directory
def classify_existing_files(directory):
    files = os.listdir(directory)
    total_files = len(files)
    for i, filename in enumerate(files):
        classify_file(directory, filename)
        progress_bar.value = int((i + 1) / total_files * 100)

class FileEventHandler(FileSystemEventHandler):
    def __init__(self, directory):
        self.directory = directory
    
    def on_created(self, event):
        if not event.is_directory:
            classify_file(self.directory, os.path.basename(event.src_path))

def start_monitoring(directory):
    # Create necessary directories
    create_directories(directory)
    
    # Classify existing files
    classify_existing_files(directory)

    # Set up the event handler
    event_handler = FileEventHandler(directory)
    observer = Observer()
    observer.schedule(event_handler, directory, recursive=False)
    observer.start()

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

# Start the monitoring when directory path is provided
def on_directory_input_change(change):
    directory = change['new']
    if os.path.isdir(directory):
        progress_bar.value = 0
        start_monitoring(directory)

directory_input.observe(on_directory_input_change, names='value')

# %%
import os
import time
import json
import datetime
import shutil
import ipywidgets as widgets
from IPython.display import display
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# Widget for directory input
directory_input = widgets.Text(
    value='',
    placeholder='Enter directory path',
    description='Directory:',
    disabled=False
)

# Progress bar
progress_bar = widgets.IntProgress(
    value=0,
    min=0,
    max=100,
    step=1,
    description='Progress:',
    bar_style='info',
    orientation='horizontal'
)

# Display widgets
display(directory_input)
display(progress_bar)

# Enhanced dictionary of file categories and their extensions
categories = {
    'Images': ['jpeg', 'jpg', 'png', 'gif', 'bmp', 'tiff'],
    'PDFs': ['pdf'],
    'Documents': ['doc', 'docx', 'txt', 'rtf', 'odt'],
    'Spreadsheets': ['xls', 'xlsx', 'ods'],
    'Presentations': ['ppt', 'pptx', 'odp'],
    'Datasets': ['csv', 'xlsx', 'json', 'xml', 'sql', 'jsonl', 'ftm.json'],
    'Videos': ['mp4', 'mkv', 'avi', 'mov', 'wmv'],
    'Audio': ['mp3', 'wav', 'aac', 'flac'],
    'Archives': ['zip', 'rar', 'tar', 'gz', '7z'],
    'Scripts': ['py', 'js', 'sh', 'bat'],
    'Executables': ['exe', 'bin', 'msi'],
    'Web': ['html', 'htm', 'css', 'js']
}

# Create a reverse lookup dictionary for file extensions
extension_to_category = {ext: category for category, extensions in categories.items() for ext in extensions}

def create_directories(directory):
    for category in categories:
        os.makedirs(os.path.join(directory, category), exist_ok=True)

# Function to classify a file
def classify_file(directory, filename):
    # Find the file extension
    extension = os.path.splitext(filename)[-1][1:]

    # Get the category from the reverse lookup dictionary
    category = extension_to_category.get(extension)
    if category:
        # Construct the file paths
        source_path = os.path.join(directory, filename)
        dest_path = os.path.join(directory, category, filename)

        # Move the file
        os.rename(source_path, dest_path)
        print(f'Moved {filename} to {category}')

# Classify all existing files in the directory
def classify_existing_files(directory):
    files = os.listdir(directory)
    total_files = len(files)
    for i, filename in enumerate(files):
        classify_file(directory, filename)
        progress_bar.value = int((i + 1) / total_files * 100)

# Function to create the gathered folder and move category folders into it
def gather_folders(directory):
    gathered_folder_name = f'gathered on {datetime.datetime.now().strftime("%Y-%m-%d")}'
    gathered_folder_path = os.path.join(directory, gathered_folder_name)
    os.makedirs(gathered_folder_path, exist_ok=True)

    for category in categories:
        category_path = os.path.join(directory, category)
        if os.path.exists(category_path):
            shutil.move(category_path, gathered_folder_path)
    
    return gathered_folder_path

# Function to create a JSON file with the directory structure
def create_json_structure(directory, json_path):
    structure = {}
    for root, dirs, files in os.walk(directory):
        relative_path = os.path.relpath(root, directory)
        if relative_path == '.':
            relative_path = ''
        structure[relative_path] = {'dirs': dirs, 'files': files}
    
    with open(json_path, 'w') as json_file:
        json.dump(structure, json_file, indent=4)

class FileEventHandler(FileSystemEventHandler):
    def __init__(self, directory):
        self.directory = directory
    
    def on_created(self, event):
        if not event.is_directory:
            classify_file(self.directory, os.path.basename(event.src_path))

def start_monitoring(directory):
    # Create necessary directories
    create_directories(directory)
    
    # Classify existing files
    classify_existing_files(directory)

    # Gather all category folders
    gathered_folder_path = gather_folders(directory)

    # Create a JSON file with the directory structure
    json_path = os.path.join(gathered_folder_path, 'directory_structure.json')
    create_json_structure(gathered_folder_path, json_path)

    # Set up the event handler
    event_handler = FileEventHandler(directory)
    observer = Observer()
    observer.schedule(event_handler, directory, recursive=False)
    observer.start()

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

# Start the monitoring when directory path is provided
def on_directory_input_change(change):
    directory = change['new']
    if os.path.isdir(directory):
        progress_bar.value = 0
        start_monitoring(directory)

directory_input.observe(on_directory_input_change, names='value')
# Out:
# Text(value='', description='Directory:', placeholder='Enter directory path')
# IntProgress(value=0, bar_style='info', description='Progress:')
# Moved (1) Стрічка LinkedIn.mp4 to Videos
# Moved 1203002759730514.20kQ4YStUWMAArBl1nQp_height640.png to Images
# Moved 2022-state-of-cryptocurrency-investigations-survey.pdf to PDFs
# Moved 21413_fcc1aef91ab038b33e7c61d6d5439fb0.docx to Documents
# Moved 2609_MARKED_White Trezor acc all transactions.xlsx to Datasets
# Moved 31909_21aa533f6ae2578290434c8ea47428b1.doc to Documents
# Moved 3BMEXniirhvGm3rfmZo49J1duij8rg3rmJ.json to Datasets
# Moved 5278222165348565702_121.jpg to Images
# Moved 5280963625793732751_121.jpg to Images
# Moved 5280963625793732752_121.jpg to Images
# Moved 5330296607998066891_121.jpg to Images
# Moved 5330296607998066919_120.jpg to Images
# Moved 5_1_SR Amount DebitCreditUsage.xls to Spreadsheets
# Moved 7z2201-x64.exe to Executables
# Moved ACFrOgBL1diqkT2dZ2k2oWEaZhI2ypdUdXxC0JniQVcdwi0fV6aVPFQNazId7g0QD5KQ-bM0qbHGHMqYRTLqvw_YsdRNKxiq_cAx_05oIrlAuzIdbvlWMgRFw0Oxhs9Dp4JCiZknWKSC6jDsYwrw.pdf to PDFs
# Moved aida64extreme675.zip to Archives
# Moved Appearance Menu Mod-790-1-14-5-1663839145.zip to Archives
# Moved Appearance Menu Mod-790-1-14-6-1665368619.zip to Archives
# Moved Application form.docx to Documents
# Moved Appointment_Declaration_director.docx to Documents
# Moved Arcadia_Mk_VI_Full-Remake-3403-3-1-1665110959.zip to Archives
# Moved Arcadia_Mk_VI_Hotfix-3403-3-2a-1665333841.zip to Archives
# Moved AR_2021-11-01.docx to Documents
# Moved Bill.pdf to PDFs
# Moved BlockchainLawEnforcementApr2022.pdf to PDFs
# Moved BlockchainLicensesJuly2022.pdf to PDFs
# Moved Blockchain_PressKit.zip to Archives
# Moved BL_Details_202210120933018454.pdf to PDFs
# Moved BL_Details_202210120938254304.pdf to PDFs
# Moved bookmarks_26June2022.zip to Archives
# Moved Bootcut No Stitching-4689-1-0-1655675325.zip to Archives
# Moved Button-Up Shirt--short sleeve-2927-1-0-1627977321.7z to Archives
# Moved CabinetResolution_582020-RegulatingBeneficialOwnerProcedure-1.pdf to PDFs
# Moved Cap colors-4293-1-1649196405.rar to Archives
# Moved COI-RAK-Sample-1542857308.pdf to PDFs
# Moved Company_Fomation_and_Management_Agreement.doc to Documents
# Moved Compliance Individual Taras.pdf to PDFs
# Moved Connection_transfers_of_Leadparty_to_3BMEXniirhvGm3rfmZo49J1duij8rg3rmJ.csv to Datasets
# Moved Copy of EQIBank Compliance Individual (1).pdf to PDFs
# Moved Copy of EQIBank Compliance Individual.pdf to PDFs
# Moved Corpo M-5285-1-6-1663642725.7z to Archives
# Moved Corpo Pants (Legendary)-2927-1-0-1627977543.7z to Archives
# Moved crs-self-certification-form-controlling-persons-om.pdf to PDFs
# Moved Crypto-Crime-Report-2022.pdf to PDFs
# Moved CrystalDiskMark8_0_4b.exe to Executables
# Moved Custom_Cluster_exposure_of_3BMEXniirhvGm3rfmZo49J1duij8rg3rmJ_USD.csv to Datasets
# Moved David's Lexington Silver-5386-0-9-1664049733.zip to Archives
# Moved deposite_history (1).pdf to PDFs
# Moved Dino Vest-4308-1-0-1652894261.zip to Archives
# Moved DJ Capital 5000 - This Fffire (Instrumental Tribute Version Originally Performed By Franz Ferdinand) (Cyberpunk Edgerunners 2022)_(audiohunter.ru).mp3 to Audio
# Moved doc.pdf to PDFs
# Moved Docker Desktop Installer.exe to Executables
# Moved docs_cebe338a-4443-4972-ba10-9dacc4c2f5bf_doc.pdf to PDFs
# Moved DroidCam.Setup.6.5.2.exe to Executables
# Moved EpocCam_Installer64_3_4_0.exe to Executables
# Moved EQI BANK-20221005T142632Z-001.zip to Archives
# Moved Eqibank Board Resolution.docx to Documents
# Moved EQIBank Compliance Individual (1).pdf to PDFs
# Moved EQIBank Compliance Individual (2).pdf to PDFs
# Moved EQIBank Compliance Individual (4).pdf to PDFs
# Moved EQIBank Compliance Individual-1.pdf to PDFs
# Moved EQIBank Compliance Individual-2.pdf to PDFs
# Moved EQIBank Compliance Individual.pdf to PDFs
# Moved Extra Lifepath Clothes - Legacy-5317-1-0-1664068212.zip to Archives
# Moved Extra Lifepath Clothes - Scripts-5317-1-0-1664078691.zip to Archives
# Moved FATCA CRS Entity Self Certification Form (2).docx to Documents
# Moved FATCA CRS Entity Self Certification Form (3).docx to Documents
# Moved FATCA CRS Entity Self Certification Form - Copy (1).docx to Documents
# Moved FATCA CRS Entity Self Certification Form - Copy.docx (1).pdf to PDFs
# Moved FATCA CRS Entity Self Certification Form - Copy.docx.pdf to PDFs
# Moved FATCA CRS Entity Self Certification Form.docx to Documents
# Moved FATCA CRS Entity Self Certification Form.pdf to PDFs
# Moved FATCA CRS Individual Self Certification Form - Copy (1).doc to Documents
# Moved FATCA CRS Individual Self Certification Form - Oleh.docx to Documents
# Moved FATCA CRS Individual Self Certification Form -Taras(1).docx to Documents
# Moved FATCA CRS Individual Self Certification Form -Taras(2).docx to Documents
# Moved FATCA CRS Individual Self Certification Form -Taras.docx to Documents
# Moved FidelityFx Super Resolution 2.1 Beta-3001-0-8-0-beta3-1663546807.rar to Archives
# Moved final_code_english.pdf to PDFs
# Moved fw8bene.pdf to PDFs
# Moved GeForce_Experience_Beta_v3.26.0.131.exe to Executables
# Moved GeForce_Experience_v3.25.1.27.exe to Executables
# Moved GitHubDesktopSetup-x64(1).exe to Executables
# Moved GPU-Z.2.49.0.exe to Executables
# Moved GPU-Z.2.50.0.exe to Executables
# Moved images.pdf to PDFs
# Moved image_2022-09-22_09-56-02.jpg to Images
# Moved image_2022-09-22_10-13-35.jpg to Images
# Moved image_2022-09-22_10-14-06.jpg to Images
# Moved image_2022-09-22_10-14-28.jpg to Images
# Moved image_2022-09-22_10-15-02.jpg to Images
# Moved image_2022-09-22_11-17-57.jpg to Images
# Moved index.json to Datasets
# Moved individual form.pdf to PDFs
# Moved IRST Utility_Intel_17.8.1001.0_W11x64_A(1).zip to Archives
# Moved IRST_Intel_18.6.1.1016.2_W10x64W11x64_A.zip to Archives
# Moved iVCam_x64_v7.0.4.exe to Executables
# Moved Jafza-KYC_UBO-NewCompanyForm-2022.pdf to PDFs
# Moved Johnny Pants-5026-1-0-1663982405.zip to Archives
# Moved Kiroshi Optics Expanded-5672-1-0-1665059197.zip to Archives
# Moved Layered Vest-5026-1-0-1663527591.zip to Archives
# Moved license.pdf to PDFs
# Moved MaltegoSetup.JRE64.v4.3.1.exe to Executables
# Moved Members_Resolution_-_LLP.docx to Documents
# Moved Memorandum Copy.pdf to PDFs
# Moved Memorandum Copy_merged.pdf to PDFs
# Moved mono.pdf to PDFs
# Moved NDA_Person.pdf to PDFs
# Moved ndp481-devpack-enu.exe to Executables
# Moved ndp481-devpack-rus.exe to Executables
# Moved ndp481-web.exe to Executables
# Moved Netflix Anime - Cyberpunk Edgerunners OP_(audiohunter.ru).mp3 to Audio
# Moved neuro_nim_riothelmet.7z-5288-1-0-0-1663587296.7z to Archives
# Moved NodeXLBasicExcelTemplate2018Setup.exe to Executables
# Moved Nomad Female-5285-1-1663564399.7z to Archives
# Moved Nomad Male-5285-1-6-1663564447.7z to Archives
# Moved Octo_Browser_latest_win.exe to Executables
# Moved pdf24-creator-11.6.0.exe to Executables
# Moved photo_2022-09-14_15-37-21 (2).jpg to Images
# Moved photo_2022-09-14_15-37-21.jpg to Images
# Moved photo_2022-09-16_10-01-10.jpg to Images
# Moved Pleated Pants-2256-1-1631396913.zip to Archives
# Moved PowerToysSetup-0.63.0-x64.exe to Executables
# Moved privat.pdf to PDFs
# Moved Private_Company.docx to Documents
# Moved Q1_2022_institutional_framework.pdf to PDFs
# Moved Register-of-Directors-template-v1.docx to Documents
# Moved report_25-09-2022_02-29-43.pdf to PDFs
# Moved report_30-09-2022_10-03-01.pdf to PDFs
# Moved Russian translation for Missing Persons - Fixer's Hidden Gems-5126-1-4-1663537080(1).zip to Archives
# Moved Russian translation for StreetStyle - Immersive Fashion System-2992-1-5-2-1645070570.rar to Archives
# Moved Sample_of_Directors_and_Officers_Register.docx to Documents
# Moved Sample_of_Share_Register_.docx to Documents
# Moved ScanReport-kuzin.pdf to PDFs
# Moved ScanReport-шедогубов.pdf to PDFs
# Moved Screenshot 2022-09-19 at 10.01.16.png to Images
# Moved Screenshot 2022-10-13 at 08.10.25.png to Images
# Moved screenshot_3BMEXniirhvGm3rfmZo49J1duij8rg3rmJ.png to Images
# Moved Selectors f2b7a07a-65f6-480c-9f26-88a61d9b048e.csv to Datasets
# Moved Set 02 - Crocodile-4543-1-0-1653256117.zip to Archives
# Moved Shareholders_Resolution_for_appointment_and_cessation_of_auditor.docx to Documents
# Moved Shareholder_Resolution_for_Appointment_or_Cessation_of_a_director.docx to Documents
# Moved Share_Certificate_Template_for_a_Shareholder.docx to Documents
# Moved Short Coat-5026-1-0-1664243279.zip to Archives
# Moved Skundas-del-finansu-rinkos-dalyvio-veiksmu_EN(1).docx to Documents
# Moved Star Exchange FCZ 2022-10-07 $1,000 EQIBank application fee (EQIB-513).pdf to PDFs
# Moved StartAllBack_3.5.2_setup.exe to Executables
# Moved Statement_of_the_Compliance_by_the_Directors_for_amended_Articles_of_Association_Template.docx to Documents
# Moved StreetKid Cyberware-4615-1-1655037402.rar to Archives
# Moved StreetKid Female-5285-1-6-1663564497.7z to Archives
# Moved STR_Form.pdf to PDFs
# Moved takeout-20220921T122052Z-001.zip to Archives
# Moved transfers.json to Datasets
# Moved Ultimate_Beneficial_Owners_UBO_Register.xlsx to Datasets
# Moved United (UTED) __ WhiteBIT.docx to Documents
# Moved Unlock Hidden Settings with (Increased FOV - Mouse sensitivity - Zoom sensitivity - Resolution scale limit)-124-1-6-1663689771.zip to Archives
# Moved unnamed.png to Images
# Moved UserAgreement_Sept_1_2022.pdf to PDFs
# Moved Valentinos Cyberware-4615-1-1655036066.rar to Archives
# Moved Vlttrading@gmail.com .png to Images
# Moved Vlttrading@gmail.com 3.png to Images
# Moved Vlttrading@gmail.com 4.png to Images
# Moved Vlttrading@gmail.com 5. png.png to Images
# Moved Vlttrading@gmail.com 6.png to Images
# Moved WhatsMyName Web.csv to Datasets
# Moved withdraw_history (2).pdf to PDFs
# Moved WTelegramClient-master.zip to Archives
# Moved Yoros-2927-1-0-1627979434.7z to Archives
# Moved Yukata-2927-1-0-1627979491.7z to Archives
# Moved Знімок екрана 2022-09-29 132302.png to Images
# Moved Настройки.htm to Web
# Moved Оплата.png to Images
